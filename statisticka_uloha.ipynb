# %%
import pandas as pd
import plotly.express as px

# %%
data = pd.read_csv('children_per_woman_total_fertility.csv')
data
# Out:
#                   country  1800  1801  1802  1803  1804  1805  1806  1807
# 0                   Aruba  5.64  5.64  5.64  5.64  5.64  5.64  5.64  5.64  \
# 1             Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# 2                  Angola  6.93  6.93  6.93  6.93  6.93  6.93  6.93  6.94
# 3                 Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# 4    Netherlands Antilles  5.80  5.80  5.80  5.80  5.80  5.80  5.80  5.80
# ..                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 197                 Samoa  6.98  6.98  6.98  6.98  6.98  6.98  6.98  6.98
# 198                 Yemen  6.88  6.88  6.88  6.88  6.88  6.88  6.88  6.88
# 199          South Africa  6.47  6.47  6.47  6.47  6.47  6.47  6.47  6.47
# 200                Zambia  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# 201              Zimbabwe  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
#
#      1808  ...  2091  2092  2093  2094  2095  2096  2097  2098  2099  2100
# ...

# %%
columns=['country']
columns += [str(i) for i in range(1800, 2022)]
actual_data = data[columns].copy()
actual_data.sort_values(by='country', inplace=True)
actual_data
# Out:
#                    country  1800  1801  1802  1803  1804  1805  1806  1807
# 1              Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  \
# 3                  Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# 50                 Algeria  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# 2                   Angola  6.93  6.93  6.93  6.93  6.93  6.93  6.93  6.94
# 8      Antigua and Barbuda  5.00  5.00  4.99  4.99  4.99  4.98  4.98  4.97
# ..                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 194  Virgin Islands (U.S.)  5.55  5.55  5.55  5.55  5.55  5.55  5.55  5.55
# 54          Western Sahara  6.32  6.32  6.32  6.32  6.32  6.32  6.32  6.32
# 198                  Yemen  6.88  6.88  6.88  6.88  6.88  6.88  6.88  6.88
# 200                 Zambia  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# 201               Zimbabwe  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
#
# ...

# %% [markdown]
# ## Tranforming data structure a bit so it's more convenient to work with

# %%
formated_data = actual_data.transpose().reset_index()
formated_data.columns = formated_data.iloc[0]
formated_data = formated_data[1:].copy().rename(columns={'country': 'year'})
formated_data['year'] = formated_data['year'].apply(lambda x: int(x))
formated_data
# Out:
# 0    year Afghanistan Albania Algeria Angola Antigua and Barbuda Argentina
# 1    1800         7.0     4.6    6.99   6.93                 5.0       6.8  \
# 2    1801         7.0     4.6    6.99   6.93                 5.0       6.8
# 3    1802         7.0     4.6    6.99   6.93                4.99       6.8
# 4    1803         7.0     4.6    6.99   6.93                4.99       6.8
# 5    1804         7.0     4.6    6.99   6.93                4.99       6.8
# ..    ...         ...     ...     ...    ...                 ...       ...
# 218  2017        4.48    1.71    2.71   5.62                2.04      2.28
# 219  2018        4.33    1.71    2.64   5.55                2.03      2.26
# 220  2019        4.18     1.7    2.59   5.48                2.02      2.25
# 221  2020        4.04     1.7    2.54   5.41                2.01      2.23
# 222  2021         3.9     1.7    2.49   5.34                 2.0      2.22
#
# ...

# %% [markdown]
# ## Let's take a look at the number of children per year per each country

# %%
countries = formated_data.columns[1:]
fig = px.scatter(formated_data, x='year', y=countries)
fig.show()
# Out:
# <div>                            <div id="48b12933-b157-4c6a-8ceb-5f33ce2a8c23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48b12933-b157-4c6a-8ceb-5f33ce2a8c23")) {                    Plotly.newPlot(                        "48b12933-b157-4c6a-8ceb-5f33ce2a8c23",                        [{"hovertemplate":"variable=Afghanistan\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Afghanistan","showlegend":true,"x":[1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840
# ...

# %% [markdown]
# ## The impact of the WW2 on the fertility of countries which took big part in WW2 [linear regression on years 1935 - 1946]

# %%
from sklearn.linear_model import LinearRegression
# No data for England and Slovakia
ww2_countries=['Poland', 'France', 'Italy', 'Japan', 'Finland', 'Germany',
               'Austria', 'Ukraine', 'Russia', 'Czech Republic', 'Belgium', 'Netherlands', 'Luxembourg', 'USA']
ww2_countries.sort()
ww2_data = formated_data[(formated_data['year'] >= 1935) & (formated_data['year'] <= 1946)].copy()
x = ww2_data[['year']]
for country in ww2_countries:
    cur_data = ww2_data[['year', country]].copy()
    cur_data[country] = cur_data[country].apply(lambda x: float(x))
    y_country = cur_data[country]
    model = LinearRegression()
    model.fit(x, y_country)
    y_pred = model.predict(x)
    cur_data['linear_'+country] = y_pred
    fig = px.scatter(cur_data, x='year', y=[country])
    fig.add_scatter(x=cur_data['year'], y=cur_data['linear_'+country], mode='lines', name='trendline')
    fig.show()
# Out:
# <div>                            <div id="f3e29edc-f97c-4a80-b2e3-88446a72e3ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3e29edc-f97c-4a80-b2e3-88446a72e3ca")) {                    Plotly.newPlot(                        "f3e29edc-f97c-4a80-b2e3-88446a72e3ca",                        [{"hovertemplate":"variable=Austria\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Austria","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Austria","orientation":"v","showlegend":true,"x":[1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946],"xaxis":"x","y":[1.81,1.8,1.54,1.92,2.86,2.7,2.53,2.37,2.21,2.04,1.88,1.88],"yaxis":"y","type":"scatter"},{"mode":"lines","name":"trendli
# ...

# %% [markdown]
# ### Austria, Poland, Ukraine, Russia show the decrease of children per year during WW2 and for some time after it. Linear regression for Austria doesn't reflect it because of the big increase in 1939 compared to previous years.

# %% [markdown]
# ## Check whether the average fertility per country in the year 2021 is a normal distribution throughout the whole world with Shapiro-Wilk test. The null hypothesis is that the data is from the normal distribution.

# %%
import numpy as np
from scipy.stats import shapiro

data2021 = formated_data[formated_data['year'] == 2021].dropna(axis=1)
children2021 = data2021.iloc[0][1:].tolist()
children2021.sort()
children2021
# Out:
# [1.23,
#  1.24,
#  1.27,
#  1.28,
#  1.29,
#  1.3,
#  1.34,
#  1.38,
#  1.4,
#  1.42,
#  1.42,
#  1.43,
#  1.43,
#  1.43,
#  1.43,
#  1.44,
#  1.45,
#  1.45,
#  1.5,
#  1.5,
#  1.51,
#  1.51,
#  1.52,
#  1.53,
#  1.55,
#  1.55,
#  1.56,
#  1.56,
#  1.57,
#  1.57,
#  1.58,
#  1.6,
#  1.61,
#  1.61,
#  1.62,
#  1.63,
#  1.64,
#  1.64,
#  1.66,
#  1.66,
#  1.67,
#  1.67,
#  1.69,
#  1.7,
#  1.7,
#  1.7,
#  1.7,
#  1.72,
#  1.72,
#  1.73,
#  1.74,
#  1.74,
#  1.76,
#  1.76,
#  1.78,
#  1.78,
#  1.79,
#  1.79,
#  1.8,
#  1.81,
#  1.81,
#  1.81,
#  1.82,
#  1.82,
#  1.83,
#  1.84,
#  1.85,
#  1.87,
#  1.87,
#  1.88,
#  1.89,
#  1.89,
#  1.91,
#  1.91,
#  1.91,
#  1.92,
#  1.93,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.95,
#  1.95,
#  1.95,
#  1.97,
#  1.97,
#  1.97,
#  1.97,
#  1.97,
#  1.98,
#  1.98,
#  2.0,
#  2.0,
#  2.0,
#  2.04,
#  2.07,
#  2.08,
#  2.09,
#  2.1,
#  2.11,
#  2.12,
#  2.16,
#  2.18,
#  2.18,
#  2.19,
#  2.21,
#  2.22,
#  2.22,
#  2.24,
#  2.26,
#  2.26,
#  2.26,
# ...

# %%
shapiro_test = shapiro(children2021)
shapiro_test
# Out:
# ShapiroResult(statistic=0.8594654202461243, pvalue=1.1663231144765085e-12)

# %% [markdown]
# ### p-value is 1e-12, so the null hypothesis is rejected, which means that the data isn't from the normal distribution.

# %% [markdown]
# ## Check the same thing, but only for European countries

# %%
# Slovakia and Cyprus aren't in the dataframe, so I don't include them here.
eu_countries = [
    'Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Czech Republic',
    'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland',
    'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Poland',
    'Portugal', 'Romania', 'Slovenia', 'Spain', 'Sweden'
]
data2021_eu = data2021[eu_countries]
data2021_eu
# Out:
# 0   Austria Belgium Bulgaria Croatia Czech Republic Denmark Estonia Finland
# 222    1.55    1.81     1.63    1.45           1.61    1.78    1.69    1.79  \
#
# 0   France Germany  ... Lithuania Luxembourg Malta Netherlands Poland
# 222   1.97     1.5  ...       1.7       1.62  1.51        1.76   1.29  \
#
# 0   Portugal Romania Slovenia Spain Sweden
# 222     1.24    1.57     1.67  1.43   1.91
#
# [1 rows x 25 columns]

# %%
children2021_eu = data2021_eu.iloc[0].tolist()
children2021_eu.sort()
children2021_eu
# Out:
# [1.24,
#  1.29,
#  1.3,
#  1.43,
#  1.44,
#  1.45,
#  1.5,
#  1.51,
#  1.53,
#  1.55,
#  1.57,
#  1.61,
#  1.61,
#  1.62,
#  1.63,
#  1.67,
#  1.69,
#  1.7,
#  1.76,
#  1.78,
#  1.79,
#  1.81,
#  1.91,
#  1.97,
#  1.97]

# %%
shapiro_test_eu = shapiro(children2021_eu)
shapiro_test_eu
# Out:
# ShapiroResult(statistic=0.9770916104316711, pvalue=0.8220909237861633)

# %% [markdown]
# ### p-value is much more than 0.05, so the data can be from a normal distribution

# %% [markdown]
# ### let's take a look at the average value of fertility from averages per country in Europe and the standard deviation:

# %%
mean = np.mean(children2021_eu)
sd = np.std(children2021_eu)
mean, sd
# Out:
# (1.6132, 0.19466319631609874)
